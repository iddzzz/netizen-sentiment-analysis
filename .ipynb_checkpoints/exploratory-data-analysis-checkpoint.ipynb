# %% [markdown]
# # EDA

# %%
import pandas as pd
pd.set_option("display.max_colwidth", 140)

df = pd.read_csv('./data/tweet-clean.csv')
df
# Out:
#                                         id                 name  \
# 0               DedenSujanaFeb12021Simak b         Deden Sujana
# 1       MuridIslamAhmadiyahFeb12021nah say  MuridIslamAhmadiyah
# 2               risrisismanFeb12021Sebenar         risris isman
# 3      MuridIslamAhmadiyahJan312021adakah   MuridIslamAhmadiyah
# 4      MuridIslamAhmadiyahJan312021itu vid  MuridIslamAhmadiyah
# ...                                    ...                  ...
# 13610         Beritabaru.coDec12021FBTI Ta        Beritabaru.co
# 13611               KETTLERDec12021Tuhanny              KETTLER
# 13612               KETTLERDec12021Tuhanny              KETTLER
# 13613               EkajuwaDec12021#IslamM              Ekajuwa
# 13614      NugrohoAdinegoroDec12021tah ben    Nugroho Adinegoro
#
#             username          date          reply_to  \
# 0       @dedensujana   Feb 1, 2021               NaN
# 1        @MAhmadiyah   Feb 1, 2021    @akbarnugrohoa
# 2          @risrisus   Feb 1, 2021  @susipudjiastuti
# 3        @MAhmadiyah  Jan 31, 2021    @akbarnugrohoa
# 4        @MAhmadiyah  Jan 31, 2021    @akbarnugrohoa
# ...              ...           ...               ...
# 13610  @Beritabaruco   Dec 1, 2021               NaN
# 13611      @inong911   Dec 1, 2021        @AlloEfrat
# 13612      @inong911   Dec 1, 2021     @AriaDinataK1
# 13613       @ekajuwa   Dec 1, 2021               NaN
# 13614    @kangnugo85   Dec 1, 2021          @nuke168
#
#                                                                                                                                            content  \
# 0                             Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :\n@Iskandargumay1
# 1                         nah saya ulang ya. silahkan temukan pernyataan dari Ahmadiyah langsung, bahwa nabi terakhir/penutup adala Ghulam Ahmad.
# 2      Sebenarnya mengomentari \n@permadiaktivis1\n lebih politis dari pada bicara HAM, mana berani para politikus menaggapi apalagi bersuara l...
# 3                 adakah pernyataan dari Ahmadiyah bahwa nabi penutup adalah Bukan Muhammad melainkan Mirza Ghulam Ahmad? silahkan tunjukan disini
# 4      itu video udh video udh menjelaskan penafsiran ahmadiyah soal Al-Azhab : 40 , malah dibilang ga bisa jelasin ok kalau ada pertanyaan soa...
# ...                                                                                                                                            ...
# 13610  FBTI Tasikmalaya Gelar Kemah Toleransi Demi Membuka Ruang Diskusi http://dlvr.it/SDWzSp #Ahmadiyah #forumbhinnekatunggalika #kemahtoleransi
# 13611  Tuhannya Islam satu Tuhannya Yahudi satu Tuhannya Kristen 1 Tuhannya Budha satu Tuhannya Hindu satu Tuhannya Konghucu satu Tuhannya Ahma...
# 13612  Tuhannya Islam satu Tuhannya Yahudi satu Tuhannya Kristen 1 Tuhannya Budha satu Tuhannya Hindu satu Tuhannya Konghucu satu Tuhannya Ahma...
# 13613  #IslamMempersatukanKita Kata Siapa? Rosul sendiri menyatakan Islam akan terpecah mjd berapa bagian. Itu terbukti dgn adanya Sunni, Syiah...
# 13614  tah bener 7 masjid weh nya\n1. Masjid agung alun2\n2. Masjid Persis\n3. Masjid NU\n4. Masjid Muhammadiyah\n5. Masjid pks\n6. Masjid waha...
#
#        reply  retweet  like lang
# 0          0        1     2   id
# 1          1        0     0   id
# 2          0        0     1   id
# 3          0        0     0   id
# 4          1        0     0   id
# ...      ...      ...   ...  ...
# 13610      0        0     0   id
# 13611      1        0     0   id
# 13612      0        1     0   id
# 13613      0        1     0   id
# 13614      1        0     1   so
#
# [13615 rows x 10 columns]

# %% [markdown]
# ## Username

# %%
print(f'Jumlah username unik: {len(df.name.value_counts().index)}')
# Out:
# Jumlah username unik: 5587

# %%
users = df.name.value_counts().index.values
sample_tweet = df[['name', 'content']][df.name.isin(users)]
sample_tweet = sample_tweet.drop_duplicates(subset='name')
df_users = pd.DataFrame({
    'nama': df.name.value_counts().index,
    'jumlah_tweet': df.name.value_counts().values,
    'sample': sample_tweet.content.values,
}, index=[i for i in range(len(users))])
df_users.head(10)
# Out:
#                           nama  jumlah_tweet  \
# 0          MuridIslamAhmadiyah           828
# 1                 Deden Sujana           318
# 2                 bill temporo           298
# 3          Ahmadiyah Indonesia           215
# 4           Iman Mubarak Ahmad            99
# 5          IG: WarungSejarahRI            81
# 6                 نانانگ سلمان            63
# 7     Nasrun Aminullah Muchtar            55
# 8  Aphrodite Celestamine Prune            54
# 9                         iLba            54
#
#                                                                                                                                         sample
# 0                         Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :\n@Iskandargumay1
# 1                     nah saya ulang ya. silahkan temukan pernyataan dari Ahmadiyah langsung, bahwa nabi terakhir/penutup adala Ghulam Ahmad.
# 2  Sebenarnya mengomentari \n@permadiaktivis1\n lebih politis dari pada bicara HAM, mana berani para politikus menaggapi apalagi bersuara l...
# 3    Pengajian Mingguan Online\n\nTajuk: Tahrik Waqf-e-Nau\n\nDibawakan oleh: \nDepartment Tarbiyat Nasional\nJamaat Ahmadiyah Mulsim Malaysia
# 4  Widih rizik rasis k cina syiah dan ahmadiyah apa mau lo hantam pake palu jg?\nKadrun model lo yg rasis k cina syiah dan ahmadiyah apa ma...
# 5                                   banyak juga yaa. ini kalo di islam semacam nu, muhammadiyah, ahbandiyah, ahmadiyah, ldii dsb gitu gak sih?
# 6                                                                              saya menolak paham ahmadiyah berdasarkan ilmu, bukan hawa nafsu
# 7                                                                                                         Kalau Ahmadiyah dan Syiah bagaimana?
# 8  Kunjungan Intel Kodim 0703 ke Rumah Mubaligh Ahmadiyah Cilacap\n\nhttps://ayahakbar.id/2021/01/31/kunjungan-intel-kodim-0703-ke-rumah-mu...
# 9  Mirza ghulam ahmad,seorang tokoh robbaniawan islam dari Qadian ,India. Dia adalah pendiri sebuah gerakan keagamaan dalam islam,Ahmadiyah...

# %%
import matplotlib.pyplot as plt

ax = plt.hist(df_users.jumlah_tweet)
plt.title("Sebaran banyaknya users dengan berbagai jumlah tweet")
plt.xlabel("Jumlah Tweet")
plt.ylabel("Julah Users")
plt.show()
