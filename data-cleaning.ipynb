# %% [markdown]
# ## Concatenating Data

# %%
import pandas as pd
import os
from langdetect import detect
pd.set_option("display.max_colwidth", 140) # to set the column width of the table output

# %%
tw1 = pd.read_csv("./data/tweet-01.csv")
tw2 = pd.read_csv("./data/tweet-02.csv")
tw3 = pd.read_csv("./data/tweet-03.csv")
tw4 = pd.read_csv("./data/tweet-04.csv")
tw5 = pd.read_csv("./data/tweet-05.csv")
tw6 = pd.read_csv("./data/tweet-06.csv")
tw7 = pd.read_csv("./data/tweet-07.csv")
tw8 = pd.read_csv("./data/tweet-08.csv")

tw9_1 = pd.read_csv("./data/tweet-09-05-01.csv")
tw9_2 = pd.read_csv("./data/tweet-09-07-04.csv")
tw9_3 = pd.read_csv("./data/tweet-09-10-06.csv")
tw9_4 = pd.read_csv("./data/tweet-09-30-09.csv")

tw9 = pd.concat([tw9_1, tw9_2, tw9_3, tw9_4])

tw10 = pd.read_csv("./data/tweet-10.csv")
tw11 = pd.read_csv("./data/tweet-11.csv")
tw12 = pd.read_csv("./data/tweet-12.csv")

tw10_11 = pd.concat([tw10, tw11])
tw10_11 = tw10_11.drop_duplicates()
# tw10_11[tw10_11.duplicated(keep=False)].sort_values('id')
tw10_12 = pd.concat([tw10_11, tw12])
tw10_12 = tw10_12.drop_duplicates()
# tw10_12[tw10_12.duplicated(keep=False)].sort_values('id')
tw9 = tw9.drop_duplicates()
# tw9[tw9.duplicated(keep=False)].sort_values('id')
tw9_12 = pd.concat([tw9, tw10_12])
tw9_12 = tw9_12.drop_duplicates()
tw9_12[tw9_12.duplicated(keep=False)].sort_values('id')
# Out:
# Empty DataFrame
# Columns: [id, name, username, date, reply_to, content, reply, retweet, like]
# Index: []

# %%
df = pd.concat([tw1, tw2, tw3, tw4, tw5, tw6, tw7, tw8, tw9_12])
df = df.drop_duplicates()
df[df.duplicated(keep=False)].sort_values('id')
# Out:
# Empty DataFrame
# Columns: [id, name, username, date, reply_to, content, reply, retweet, like]
# Index: []

# %%
df = df.reset_index()
df.shape
# Out:
# (13958, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13958 entries, 0 to 13957
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     13958 non-null  int64
#  1   id        13958 non-null  object
#  2   name      13883 non-null  object
#  3   username  13852 non-null  object
#  4   date      13957 non-null  object
#  5   reply_to  7257 non-null   object
#  6   content   13957 non-null  object
#  7   reply     5569 non-null   float64
#  8   retweet   3196 non-null   object
#  9   like      5826 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#               index        reply
# count  13958.000000  5569.000000
# mean     640.459235     3.160532
# std      532.486864    14.381742
# min        0.000000     1.000000
# 25%      233.000000     1.000000
# 50%      472.000000     1.000000
# 75%      916.000000     2.000000
# max     2446.000000   396.000000

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### name

# %%
pd.set_option("display.max_colwidth", 140) # to set the column width of the table output
df[['name', 'username', 'content']][df.name.isna()].head(20)
# Out:
#      name          username  \
# 148   NaN       @terketahui
# 168   NaN       @pite_ishak
# 308   NaN     @oposananonim
# 369   NaN        @milliongs
# 1428  NaN  @alfiarnimakhtaf
# 1540  NaN  @alfiarnimakhtaf
# 1637  NaN    @josephbachsin
# 1748  NaN          @ferr9ro
# 1817  NaN   @_butet_harahap
# 1855  NaN      @kurootsukkl
# 1955  NaN        @iyasss___
# 2386  NaN       @Abu_Hafiiz
# 2517  NaN         @radowelt
# 3270  NaN    @solechan_talk
# 3271  NaN    @solechan_talk
# 3448  NaN  @alfiarnimakhtaf
# 3451  NaN  @alfiarnimakhtaf
# 4050  NaN       @prplee3to3
# 4298  NaN          @HirmanF
# 4361  NaN       @roysamudro
#
#                                                                                                                                           content
# 148   tapi..salut dah sm org kristen/katholik..ada yang beda gini yg sesat mereka diem aja, maksudnya cukup kasih tau. coba islam wkwk syiah a...
# 168   ahmadiyah tolol, Nabi Isa AS di turun, nyet. bukan dilahir saat balik ke dunia. Si Ghulam tolol itu cm ngaku2, yg beginian lu percaya wk...
# 308   Wuuiiihh ayat perang pd masa nabi berjihad mau di cap kan sbgai dalil nya HRS...asbabun Nuzul nya sdh pernah di pelajari kah..???..soal ...
# 369                          indonesia is not actually lgbt friendly but trust me they persecuted more antek pki, ahmadiyah, dan kafir than gays
# 1428  Indonesia lulus jadi negara demokrasi, toleran dan dewasa dlm beragama kalau masjid2 kaum syiah dan ahmadiyah sudah dibuka. Temlen udah ...
# 1540  Faktanya belum terjadi begitu.  Masih normatif. Muslim syiah, ahmadiyah samsek blm menikmati kebebasan.  Bahkan sy perhatikan justeru se...
# 1637  Maka sebagai sesama saudara muslim dan muslimah, menghentikan pemikiran dan tindakan sesat seperti ini adalah tanggung jawab kita sebaga...
# 1748                                              Ahmadiyah movement moving bare brave these days, they'll know about when the real Messiah comes
# 1817  Perang saudara Ambon, terjadi di jaman Habibie, mbak. Bertahun-tahun karena \n@DivHumas_Polri\n dan \n@Puspen_TNI\n ikut bertikai.\n\nPe...
# 1855                                                                                                                gw ahmadiyah lu jangan pitnah
# 1955                                                                                                                          MuAh Mu, Ahmadiyah.
# 2386  Ya kalo udah ngaku punya nabi stlh Rasulullah udah jelas sesatny....\n\nKalo syiah kan taqiyah trs...ngaku Islam tp mncela banyak sahaba...
# 2517  btw ngebuzzer di israel ada orang islam arab sih biasa banget. tau ga di israel ada kota haifa pusatnya komunitas ahmadiyah & agama baha...
# 3270  Masalahnya om, ahmadiyah itu bukan agama sendiri dan diakui pemerintah, tp mengaku islam dengan ajaran yg tidak sesuai Quran dan hadists...
# 3271  Dari dulu ga ada yg bisa nangkap poin ini, tp selalu menonjolkan prulalisme, kecuali kalo ahmadiyah declare sbg agama sendiri dan diakui...
# 3448  Jangan ngarep  palestina bisa bebas dari penjajahan, selama umat muslim masih mengkafirkan kaum syiah dan ahmadiyah seenak bacotnya, dan...
# 3451  Kaga usah sok2an musingin  palestina, yg deket2 aja dulu tengok; muslim syiah dan ahmadiyah yang dikafirkan, hidup dipengungsian di nega...
# 4050                                                                                                        Astaghfirullah baru tau yg Ahmadiyah
# 4298                                                                                 Mau nanya .\nJiL,syiah ,Ahmadiyah mana yg paling melenceng ?
# 4361  Suneo Rachel Ciuman Olin Zara #SedekatSahabat \n32 GB Jonatan Christie Ginting Rans Indosiar Ngilu The Daddies Ahmadiyah Ridho Ginting M...

# %% [markdown]
# ### username

# %%
df[['name', 'username', 'content']][df.username.isna()].head(20)
# Out:
#                                                     name username  \
# 1164           RAKYAT BERSATU MELAWAN KOMUNIS IMPERIALIS      NaN
# 1511  Anti Feodalism Aparteid Unfairness Racism Ibn Xine      NaN
# 1552  Anti Feodalism Aparteid Unfairness Racism Ibn Xine      NaN
# 1629    Agama Kepercayaan Adat Nusantara (GBMYLKSKVXYWQ)      NaN
# 1874                Buzzer NKRI HABBUL WATHON MINAL IMAN      NaN
# 2091                       Gerombolan BAJINGAN Tengik...      NaN
# 2497                         Anaknya Odin garis gak lucu      NaN
# 2498                       DANTALION DUSKY PRAYER LETTER      NaN
# 2501    Agama Kepercayaan Adat Nusantara (GBMYLKSKVXYWQ)      NaN
# 2502                         Anaknya Odin garis gak lucu      NaN
# 2505                         Anaknya Odin garis gak lucu      NaN
# 2520                         Aphrodite Celestamine Prune      NaN
# 2522                         Aphrodite Celestamine Prune      NaN
# 2689                         Aphrodite Celestamine Prune      NaN
# 2694                           Kertaradjasa Jayawardhana      NaN
# 2727                           Kertaradjasa Jayawardhana      NaN
# 2740                      Ujeng yg bangga dg 75 follower      NaN
# 2741                      Ujeng yg bangga dg 75 follower      NaN
# 2743                           Kertaradjasa Jayawardhana      NaN
# 2762                      Ujeng yg bangga dg 75 follower      NaN
#
#                                                                                                                                           content
# 1164                                                                                  2005 2008 ketika ahmadiyah jadi wayang , dia ada bersamaan.
# 1511  Ya benar saya selalu tertarik dan belajar Syiah, LDII, Ahmadiyah kalau tidak, tidak tahu mereka. Apalagi Islam liberal. Lebih merusak la...
# 1552  Jadi yang direkrut untuk melawan umat Islam dan memusnahkan ajaran Islam itu JIL, Syiah, LDII, Ahmadiyah, semua dengan jelas diketahui u...
# 1629  (KTP).\n\nKiai asal Tasikmalaya, Jawa Barat ini ini mencontohkan JAI (Jemaah Ahmadiyah Indonesia) yang kebetulan banyak penganutnya di K...
# 1874                                                                                   Munarman woii Ahmadiyah pihak yg terzolimi loe bela tidak?
# 2091                                                                  Macam hapal aja ente sama Alfateha...sok2an doain aliran sesat Ahmadiyah...
# 2497                                                                    Yang lebih parah kondisinya Ahmadiyah. Mereka disuruh bikin agama sendiri
# 2498  Ya beda nasib dgn nabi ahmadiyah dibuatkan sanctuary & dakwahnya difasilitasi inggris, syiah akidahnya sesat tapi gak ada yg tertarik bu...
# 2501  Belum lagi yang syiah & ahmadiyah yang dianggap bukan islam , belum lagi juga para penghayat kepercayaan pada mau ganti status islam di ...
# 2502  Sunni : Syiah bukan Islam\nSyiah : Sunni bukan Islam\nSunni&Syiah : Ahmadiyah bikin agama sendiri saja, jangan nempel Islam\nSalafi : Sy...
# 2505  Kata kadrun, "saudara muslim itu bagai satu tubuh," prett. Buktinya masih persekusi Ahmadiyah. Padahal Tuhannya sama, nabinya juga sama,...
# 2520  kl yg belum punya agama.silahkam eksplorasi apa mau islam, kristen, budha, hindu, syiah atau ahmadiyah atau apa terserah dan gak usah di...
# 2522  intinya org gak akan bersepakat di hal2 yy gak bener ,logika dan akal sehatnya demikian. org udah punya pilihan agama dipaksa pindsh ke ...
# 2689  ada koruptor, sipilis, islamohobia, kristenisasi, pki, syiah, ahmadiyah, kebodohan, asusila, amoral ibarat tubuh banyak oenyakit penyert...
# 2694                                                        Silakan minta legitimasi kepada MUI. Dan buat pernyataan kalau Ahmadiyah tidak sesat.
# 2727                                                                              Ahmadiyah sama saja dengan Syiah. Sama-sama taqiyah dan ngeyel.
# 2740                                                              Satu pertanyaan lagi, kenapa Khalifah Ahmadiyah memakai "Sir" didepan namanya ?
# 2741  Kami hanya memiliki sikap, jika Ahmadiyah tetap mengatakan pendirinya atau siapapun sebagai Nabi Penerus/Imam Mahdi, maka Ahmadiyah bera...
# 2743                                                                                              Ahmadiyah kan sesat\nAkidahnya pantas "dihajar"
# 2762                                                         Islam kenapa ngaku ahmadiyah atau Islam Ahmadiyah ??\nBedanya prinsipil nya dimana ?

# %%
df[['name', 'username', 'content']][df.username.isna() & df.name.isna()]
# Out:
# Empty DataFrame
# Columns: [name, username, content]
# Index: []

# %% [markdown]
# No sample with null value in both name & username. Let's fill username with name and vice versa

# %%
df.name.fillna(df['username'][df.name.isna()], inplace=True)
df[['name', 'username', 'content']][df.index == 148]
# Out:
#             name     username  \
# 148  @terketahui  @terketahui
#
#                                                                                                                                          content
# 148  tapi..salut dah sm org kristen/katholik..ada yang beda gini yg sesat mereka diem aja, maksudnya cukup kasih tau. coba islam wkwk syiah a...

# %%
df.username.fillna(df['name'][df.username.isna()], inplace=True)
df[['name', 'username', 'content']][df.index == 1164]
# Out:
#                                            name  \
# 1164  RAKYAT BERSATU MELAWAN KOMUNIS IMPERIALIS
#
#                                        username  \
# 1164  RAKYAT BERSATU MELAWAN KOMUNIS IMPERIALIS
#
#                                                           content
# 1164  2005 2008 ketika ahmadiyah jadi wayang , dia ada bersamaan.

# %% [markdown]
# ### Date

# %%
df[['name', 'username', 'content', 'date']][df.date.isna()]
# Out:
#                name        username  \
# 2813  Taylor Nieman  @Taylor_Nieman
#
#                                                                    content  \
# 2813  Now you can learn a language just by reading your favorite websites.
#
#      date
# 2813  NaN

# %% [markdown]
# The tweet with nan value in date is an advertisement. Let's drop it

# %%
df.dropna(subset='date', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13957 entries, 0 to 13957
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     13957 non-null  int64
#  1   id        13957 non-null  object
#  2   name      13957 non-null  object
#  3   username  13957 non-null  object
#  4   date      13957 non-null  object
#  5   reply_to  7257 non-null   object
#  6   content   13956 non-null  object
#  7   reply     5568 non-null   float64
#  8   retweet   3195 non-null   object
#  9   like      5825 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
print(df['date'][df.date == 'Aug 2, 2021'])
def convert_date(text: str):
    month_dict = {
        'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04',
        'May': '05', 'Jun': '06', 'Jul': '07', 'Aug': '08',
        'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12'
    }
    bulan = text.split(' ')[0]
    bulan = month_dict[bulan]
    tahun = text.split(' ')[-1]
    tanggal = text.split(',')[0].split(' ')[-1]
    tanggal = tanggal if len(tanggal) == 2 else ('0' + tanggal)
    return f'{tahun}-{bulan}-{tanggal}'
# Out:
# 5659    Aug 2, 2021
# 5660    Aug 2, 2021
# 5661    Aug 2, 2021
# 5662    Aug 2, 2021
# 5663    Aug 2, 2021
# 5664    Aug 2, 2021
# 5665    Aug 2, 2021
# 5666    Aug 2, 2021
# 5667    Aug 2, 2021
# 5668    Aug 2, 2021
# 5669    Aug 2, 2021
# 5670    Aug 2, 2021
# 5671    Aug 2, 2021
# 5672    Aug 2, 2021
# 5673    Aug 2, 2021
# 5674    Aug 2, 2021
# 5675    Aug 2, 2021
# 5676    Aug 2, 2021
# 5677    Aug 2, 2021
# 5678    Aug 2, 2021
# Name: date, dtype: object

# %%
df.date = df.date.apply(convert_date)
df.date = pd.to_datetime(df.date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13957 entries, 0 to 13957
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     13957 non-null  int64
#  1   id        13957 non-null  object
#  2   name      13957 non-null  object
#  3   username  13957 non-null  object
#  4   date      13957 non-null  datetime64[ns]
#  5   reply_to  7257 non-null   object
#  6   content   13956 non-null  object
#  7   reply     5568 non-null   float64
#  8   retweet   3195 non-null   object
#  9   like      5825 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 1.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13957 entries, 0 to 13957
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     13957 non-null  int64
#  1   id        13957 non-null  object
#  2   name      13957 non-null  object
#  3   username  13957 non-null  object
#  4   date      13957 non-null  datetime64[ns]
#  5   reply_to  7257 non-null   object
#  6   content   13956 non-null  object
#  7   reply     5568 non-null   float64
#  8   retweet   3195 non-null   object
#  9   like      5825 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ### reply_to

# %%
df[['name', 'username', 'content', 'reply_to']][df.reply_to.isna()]
# Out:
#                       name        username  \
# 0             Deden Sujana    @dedensujana
# 5         Fuad Ahmad Nasir    @fuadahmad88
# 7                 dont cry      @_mediocry
# 9      Robby Satya Andhika        @robbysa
# 10      Iman Mubarak Ahmad  @imanmubarak_a
# ...                    ...             ...
# 13949         Deden Sujana    @dedensujana
# 13951              Septian  @Septianaji_20
# 13952         bill temporo    @BillTemporo
# 13953        Beritabaru.co   @Beritabaruco
# 13956              Ekajuwa        @ekajuwa
#
#                                                                                                                                            content  \
# 0                             Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :\n@Iskandargumay1
# 5        Pengajian Mingguan Online\n\nTajuk: Tahrik Waqf-e-Nau\n\nDibawakan oleh: \nDepartment Tarbiyat Nasional\nJamaat Ahmadiyah Mulsim Malaysia
# 7                                       banyak juga yaa. ini kalo di islam semacam nu, muhammadiyah, ahbandiyah, ahmadiyah, ldii dsb gitu gak sih?
# 9                                                                                                             Kalau Ahmadiyah dan Syiah bagaimana?
# 10     Kunjungan Intel Kodim 0703 ke Rumah Mubaligh Ahmadiyah Cilacap\n\nhttps://ayahakbar.id/2021/01/31/kunjungan-intel-kodim-0703-ke-rumah-mu...
# ...                                                                                                                                            ...
# 13949  Official Trailer : "TITIK TERANG AHMADIYAH".\n\nVideo dokumenter ini menceritakan kisah tentang para tokoh Dayak Kalimantan Barat yang m...
# 13951                                Walaupun dekat dengan Sekte Ahmadiyah,\ntidak pernah sekalipun membenarkan Sekte nya.\nSama-sama dalam Sosial
# 13952                                                                                              GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR
# 13953  FBTI Tasikmalaya Gelar Kemah Toleransi Demi Membuka Ruang Diskusi http://dlvr.it/SDWzSp #Ahmadiyah #forumbhinnekatunggalika #kemahtoleransi
# 13956  #IslamMempersatukanKita Kata Siapa? Rosul sendiri menyatakan Islam akan terpecah mjd berapa bagian. Itu terbukti dgn adanya Sunni, Syiah...
#
#       reply_to
# 0          NaN
# 5          NaN
# 7          NaN
# 9          NaN
# 10         NaN
# ...        ...
# 13949      NaN
# 13951      NaN
# 13952      NaN
# 13953      NaN
# 13956      NaN
#
# [6700 rows x 4 columns]

# %%
df.reply_to = df.reply_to.astype(str)

# %% [markdown]
# ### content

# %%
df[['name', 'username', 'content', 'reply_to']][df.content.isna()]
# Out:
#                 name          username content          reply_to
# 2428  insanduniafana  @_insanduniafana     NaN  @tambaljam24ban_

# %%
df.dropna(subset='content', inplace=True)

# %%
df[['name', 'username', 'content', 'reply_to']][df.content.isna()]
# Out:
# Empty DataFrame
# Columns: [name, username, content, reply_to]
# Index: []

# %% [markdown]
# ### reply
# Number of replies

# %%
df[['name', 'username', 'content', 'reply']][df.reply.isna()].head()
# Out:
#                   name      username  \
# 0         Deden Sujana  @dedensujana
# 2         risris isman     @risrisus
# 3  MuridIslamAhmadiyah   @MAhmadiyah
# 5     Fuad Ahmad Nasir  @fuadahmad88
# 7             dont cry    @_mediocry
#
#                                                                                                                                        content  \
# 0                         Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :\n@Iskandargumay1
# 2  Sebenarnya mengomentari \n@permadiaktivis1\n lebih politis dari pada bicara HAM, mana berani para politikus menaggapi apalagi bersuara l...
# 3             adakah pernyataan dari Ahmadiyah bahwa nabi penutup adalah Bukan Muhammad melainkan Mirza Ghulam Ahmad? silahkan tunjukan disini
# 5    Pengajian Mingguan Online\n\nTajuk: Tahrik Waqf-e-Nau\n\nDibawakan oleh: \nDepartment Tarbiyat Nasional\nJamaat Ahmadiyah Mulsim Malaysia
# 7                                   banyak juga yaa. ini kalo di islam semacam nu, muhammadiyah, ahbandiyah, ahmadiyah, ldii dsb gitu gak sih?
#
#    reply
# 0    NaN
# 2    NaN
# 3    NaN
# 5    NaN
# 7    NaN

# %%
df.reply.fillna(0, inplace=True)
df.reply = df.reply.astype(int)
df[['name', 'username', 'content', 'reply']][df.reply == 0].head()
# Out:
#                   name      username  \
# 0         Deden Sujana  @dedensujana
# 2         risris isman     @risrisus
# 3  MuridIslamAhmadiyah   @MAhmadiyah
# 5     Fuad Ahmad Nasir  @fuadahmad88
# 7             dont cry    @_mediocry
#
#                                                                                                                                        content  \
# 0                         Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :\n@Iskandargumay1
# 2  Sebenarnya mengomentari \n@permadiaktivis1\n lebih politis dari pada bicara HAM, mana berani para politikus menaggapi apalagi bersuara l...
# 3             adakah pernyataan dari Ahmadiyah bahwa nabi penutup adalah Bukan Muhammad melainkan Mirza Ghulam Ahmad? silahkan tunjukan disini
# 5    Pengajian Mingguan Online\n\nTajuk: Tahrik Waqf-e-Nau\n\nDibawakan oleh: \nDepartment Tarbiyat Nasional\nJamaat Ahmadiyah Mulsim Malaysia
# 7                                   banyak juga yaa. ini kalo di islam semacam nu, muhammadiyah, ahbandiyah, ahmadiyah, ldii dsb gitu gak sih?
#
#    reply
# 0      0
# 2      0
# 3      0
# 5      0
# 7      0

# %% [markdown]
# ### retweet
# Number of retweets

# %%
df[['name', 'username', 'content', 'retweet']].sample(5, random_state=1)
# Out:
#                      name         username  \
# 825             Xavier919     @avatarcs999
# 6837              Supardi       @mbahdoro1
# 10642          Indra Baso    @NusantaraNol
# 11666  Pusat Berita Islam         @PBIslam
# 8955         Tukang Rosok  @tukangrosok___
#
#                                                                                                                                            content  \
# 825    Jadi ini semua anggota Ahmadiyah salah paham??? Ancaman itu cuma main-main saja? Ngk serius maksud lu???\n\nhttps://news.detik.com/berit...
# 6837                                        Kenapa namanya masjid Ahmadiyah, terus apa bedanya dengan masjid masjid yang sudah ini .\nSerius nanya
# 10642                                                                                                                Tolong sampaikan ke Ahmadiyah
# 11666                                                          Empat Ormas Islam Keluarkan Penyataan, Ajak Ahmadiyah Kembali pada Islam yang Benar
# 8955   Dlm sejarah berdirinya NKRI belum pernah Jama'ah Ahmadiyah mengusik ketenangan sesama warga Negara Indonesia.\nMelainkan Ikut berjuang d...
#
#       retweet
# 825       NaN
# 6837      NaN
# 10642     NaN
# 11666     NaN
# 8955     67.0

# %%
def isthisnumeric(val):
    val = str(val)
    val = val.replace('.', '')
    if val.isnumeric():
        return 1
    else:
        return 0

df.retweet.fillna(0, inplace=True)
df['retweet_isnumeric'] = df.retweet.apply(lambda x: isthisnumeric(x))
df[['username', 'content', 'retweet', 'retweet_isnumeric']][df.retweet_isnumeric == 0]
# Out:
#             username  \
# 4943  @malakmalakmal
# 7775    @AlissaWahid
#
#                                                                                                                                           content  \
# 4943                        Dalam bukunya, "Pelajaran Agama Islam", Buya Hamka sudah menjelaskan dua aliran sesat, yaitu Ahmadiyah dan Baha'iyah.
# 7775  Sekelompok orang mengatasnamakan umat Islam merusak bangunan masjid Ahmadiyah di Sintang. Apapun alasannya, ini tindakan melanggar hukum...
#
#      retweet  retweet_isnumeric
# 4943    1.7K                  0
# 7775    1.2K                  0

# %%
df = df.copy()
df['retweet'][df.retweet_isnumeric == 0] = df['retweet'][df.retweet_isnumeric == 0].apply(lambda x: x.replace('.', '').replace('K', '00'))
df[['username', 'content', 'retweet', 'retweet_isnumeric']][df.retweet_isnumeric == 0]
# Out:
# <ipython-input-27-277fedd9cb6d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['retweet'][df.retweet_isnumeric == 0] = df['retweet'][df.retweet_isnumeric == 0].apply(lambda x: x.replace('.', '').replace('K', '00'))
#             username  \
# 4943  @malakmalakmal
# 7775    @AlissaWahid
#
#                                                                                                                                           content  \
# 4943                        Dalam bukunya, "Pelajaran Agama Islam", Buya Hamka sudah menjelaskan dua aliran sesat, yaitu Ahmadiyah dan Baha'iyah.
# 7775  Sekelompok orang mengatasnamakan umat Islam merusak bangunan masjid Ahmadiyah di Sintang. Apapun alasannya, ini tindakan melanggar hukum...
#
#      retweet  retweet_isnumeric
# 4943    1700                  0
# 7775    1200                  0

# %%
df.retweet = df.retweet.astype(int)
df[['name', 'username', 'content', 'retweet']].sample(5, random_state=1)
# Out:
#                      name         username  \
# 825             Xavier919     @avatarcs999
# 6837              Supardi       @mbahdoro1
# 10642          Indra Baso    @NusantaraNol
# 11666  Pusat Berita Islam         @PBIslam
# 8955         Tukang Rosok  @tukangrosok___
#
#                                                                                                                                            content  \
# 825    Jadi ini semua anggota Ahmadiyah salah paham??? Ancaman itu cuma main-main saja? Ngk serius maksud lu???\n\nhttps://news.detik.com/berit...
# 6837                                        Kenapa namanya masjid Ahmadiyah, terus apa bedanya dengan masjid masjid yang sudah ini .\nSerius nanya
# 10642                                                                                                                Tolong sampaikan ke Ahmadiyah
# 11666                                                          Empat Ormas Islam Keluarkan Penyataan, Ajak Ahmadiyah Kembali pada Islam yang Benar
# 8955   Dlm sejarah berdirinya NKRI belum pernah Jama'ah Ahmadiyah mengusik ketenangan sesama warga Negara Indonesia.\nMelainkan Ikut berjuang d...
#
#        retweet
# 825          0
# 6837         0
# 10642        0
# 11666        0
# 8955        67

# %% [markdown]
# ### like
# Number of likes

# %%
df[['name', 'username', 'content', 'like']].sample(5, random_state=1)
# Out:
#                      name         username  \
# 825             Xavier919     @avatarcs999
# 6837              Supardi       @mbahdoro1
# 10642          Indra Baso    @NusantaraNol
# 11666  Pusat Berita Islam         @PBIslam
# 8955         Tukang Rosok  @tukangrosok___
#
#                                                                                                                                            content  \
# 825    Jadi ini semua anggota Ahmadiyah salah paham??? Ancaman itu cuma main-main saja? Ngk serius maksud lu???\n\nhttps://news.detik.com/berit...
# 6837                                        Kenapa namanya masjid Ahmadiyah, terus apa bedanya dengan masjid masjid yang sudah ini .\nSerius nanya
# 10642                                                                                                                Tolong sampaikan ke Ahmadiyah
# 11666                                                          Empat Ormas Islam Keluarkan Penyataan, Ajak Ahmadiyah Kembali pada Islam yang Benar
# 8955   Dlm sejarah berdirinya NKRI belum pernah Jama'ah Ahmadiyah mengusik ketenangan sesama warga Negara Indonesia.\nMelainkan Ikut berjuang d...
#
#       like
# 825    NaN
# 6837     2
# 10642  NaN
# 11666  NaN
# 8955   146

# %%
df.like.fillna(0, inplace=True)
df['like_isnumeric'] = df.like.apply(lambda x: isthisnumeric(x))
df[['username', 'content', 'like', 'like_isnumeric']][df.like_isnumeric == 0]
# Out:
#                                username  \
# 259                          @IrutPagut
# 1939                         @Barack_AM
# 2181                      @_ekokuntadhi
# 3132   Ulil Abshar-Abdalla #SudahVaksin
# 3327                       @AlissaWahid
# 4536                     @NurazizaShima
# 4943                     @malakmalakmal
# 7668                          @saidiman
# 7774                       @AlissaWahid
# 7775                       @AlissaWahid
# 8177                    @emerson_yuntho
# 8634                      @_ekokuntadhi
# 8939                      @_ekokuntadhi
# 9190                          @sahaL_AS
# 10856                       @AgoesAguss
# 10873                   @emerson_yuntho
# 12678                      @TaufikDamas
#
#                                                                                                                                            content  \
# 259    FOTO RAFI AHMAD DAN KAKEKNYA "MALIK AZIS AHMAD KHAN" ASAL PAKISTAN.\nBanyak yang belum Tau kalau Rafi Ahmad Cucu dari Penyebar Aliran Se...
# 1939   Dulu Istiqlal dibangun dgn dana gotong royong seluruh rakyat Indonesia tanpa melihat latarnya. Sumbangan berasal dari berbagai macam kal...
# 2181   Gak heran, kan. Di era SBY, HTI siaran langsung di TVRI kampanye khilafah dan menistai Pancasila? \n\nGak heran, pengikut Ahmadiyah dibu...
# 3132   Temen2 yg selama ini bersemangat membela kaum minoritas di Indonesia, seperti Ahmadiyah dan Syiah, akan lebih konsisten jika bersikap te...
# 3327   Minggu terakhir Ramadan ini penuh tantangan kebangsaan. Hak kelp minoritas soal seragam sekolah, hubungan Pusat Daerah yg makin tumpang-...
# 4536   "Kesalahan terburuk kita adalah ketertarikan kita pada kesalahan orang lain." -Ali bin Abi Thalib- \n\nMaljum, Malam Jumat, Joko\nAhmadi...
# 4943                         Dalam bukunya, "Pelajaran Agama Islam", Buya Hamka sudah menjelaskan dua aliran sesat, yaitu Ahmadiyah dan Baha'iyah.
# 7668   Ini bangunan warga Ahmadiyah Sintang. Dirusak para begundal di hadapan aparat tak tahu malu. Pakaian lengkap siap tempur. Jumlahnya bany...
# 7774   Syariat siapa yang mengajarkan boleh merusak bangunan orang lain, main hakim sendiri, meneror? \n\nAnda boleh tidak setuju keyakinan ora...
# 7775   Sekelompok orang mengatasnamakan umat Islam merusak bangunan masjid Ahmadiyah di Sintang. Apapun alasannya, ini tindakan melanggar hukum...
# 8177   Assalamualaikum Wr Wb Pak \n@hnurwahid\n jika dibutuhkan saya bisa bantu buatkan draft pernyataan Bapak tentang kecaman perusakan rumah ...
# 8634   Jika masjid Ahmadiyah dibakar gerombolan cingkrang. Tp umat Islam diam saja. Malah agama lain yang ikut geram. \n\nTandanya kita sebagai...
# 8939   Perhatikan gerombolan perusak masjid Ahmadiyah di Sintang : daster, celana cingkrang, jenggot. Sebagian jidat item. \n\nDimana ada gerom...
# 9190                                                                       MUI-Muhammadiyah-NU sama2 mengecam perusakan masjid Ahmadiyah di Kalbar
# 10856                                                               Si kutil PAJERO provokator pembakaran mesjid ahmadiyah sudah ditangkap guys,..
# 10873  Assalamualaikum Wr Wb Pak \n@hnurwahid\n jika dibutuhkan saya bisa bantu buatkan draft pernyataan Bapak tentang kecaman perusakan rumah ...
# 12678                       Anda boleh tidak setuju pada paham Ahmadiyah. Saya pun begitu. Tapi, menyegel tempat ibadahnya adalah tindakan biadab.
#
#        like  like_isnumeric
# 259    1.6K               0
# 1939   1.3K               0
# 2181     1K               0
# 3132   1.8K               0
# 3327   1.7K               0
# 4536     1K               0
# 4943   4.1K               0
# 7668   1.5K               0
# 7774     1K               0
# 7775   2.5K               0
# 8177   1.4K               0
# 8634   1.3K               0
# 8939   2.2K               0
# 9190     1K               0
# 10856  1.5K               0
# 10873  1.4K               0
# 12678  1.2K               0

# %%
df['like'][df.like_isnumeric == 0] = df['like'][df.like_isnumeric == 0].apply(lambda x: x.replace('.', '').replace('K', '00'))
df[['username', 'content', 'like', 'like_isnumeric']][df.like_isnumeric == 0]
# Out:
# <ipython-input-31-9b96cf76b976>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['like'][df.like_isnumeric == 0] = df['like'][df.like_isnumeric == 0].apply(lambda x: x.replace('.', '').replace('K', '00'))
#                                username  \
# 259                          @IrutPagut
# 1939                         @Barack_AM
# 2181                      @_ekokuntadhi
# 3132   Ulil Abshar-Abdalla #SudahVaksin
# 3327                       @AlissaWahid
# 4536                     @NurazizaShima
# 4943                     @malakmalakmal
# 7668                          @saidiman
# 7774                       @AlissaWahid
# 7775                       @AlissaWahid
# 8177                    @emerson_yuntho
# 8634                      @_ekokuntadhi
# 8939                      @_ekokuntadhi
# 9190                          @sahaL_AS
# 10856                       @AgoesAguss
# 10873                   @emerson_yuntho
# 12678                      @TaufikDamas
#
#                                                                                                                                            content  \
# 259    FOTO RAFI AHMAD DAN KAKEKNYA "MALIK AZIS AHMAD KHAN" ASAL PAKISTAN.\nBanyak yang belum Tau kalau Rafi Ahmad Cucu dari Penyebar Aliran Se...
# 1939   Dulu Istiqlal dibangun dgn dana gotong royong seluruh rakyat Indonesia tanpa melihat latarnya. Sumbangan berasal dari berbagai macam kal...
# 2181   Gak heran, kan. Di era SBY, HTI siaran langsung di TVRI kampanye khilafah dan menistai Pancasila? \n\nGak heran, pengikut Ahmadiyah dibu...
# 3132   Temen2 yg selama ini bersemangat membela kaum minoritas di Indonesia, seperti Ahmadiyah dan Syiah, akan lebih konsisten jika bersikap te...
# 3327   Minggu terakhir Ramadan ini penuh tantangan kebangsaan. Hak kelp minoritas soal seragam sekolah, hubungan Pusat Daerah yg makin tumpang-...
# 4536   "Kesalahan terburuk kita adalah ketertarikan kita pada kesalahan orang lain." -Ali bin Abi Thalib- \n\nMaljum, Malam Jumat, Joko\nAhmadi...
# 4943                         Dalam bukunya, "Pelajaran Agama Islam", Buya Hamka sudah menjelaskan dua aliran sesat, yaitu Ahmadiyah dan Baha'iyah.
# 7668   Ini bangunan warga Ahmadiyah Sintang. Dirusak para begundal di hadapan aparat tak tahu malu. Pakaian lengkap siap tempur. Jumlahnya bany...
# 7774   Syariat siapa yang mengajarkan boleh merusak bangunan orang lain, main hakim sendiri, meneror? \n\nAnda boleh tidak setuju keyakinan ora...
# 7775   Sekelompok orang mengatasnamakan umat Islam merusak bangunan masjid Ahmadiyah di Sintang. Apapun alasannya, ini tindakan melanggar hukum...
# 8177   Assalamualaikum Wr Wb Pak \n@hnurwahid\n jika dibutuhkan saya bisa bantu buatkan draft pernyataan Bapak tentang kecaman perusakan rumah ...
# 8634   Jika masjid Ahmadiyah dibakar gerombolan cingkrang. Tp umat Islam diam saja. Malah agama lain yang ikut geram. \n\nTandanya kita sebagai...
# 8939   Perhatikan gerombolan perusak masjid Ahmadiyah di Sintang : daster, celana cingkrang, jenggot. Sebagian jidat item. \n\nDimana ada gerom...
# 9190                                                                       MUI-Muhammadiyah-NU sama2 mengecam perusakan masjid Ahmadiyah di Kalbar
# 10856                                                               Si kutil PAJERO provokator pembakaran mesjid ahmadiyah sudah ditangkap guys,..
# 10873  Assalamualaikum Wr Wb Pak \n@hnurwahid\n jika dibutuhkan saya bisa bantu buatkan draft pernyataan Bapak tentang kecaman perusakan rumah ...
# 12678                       Anda boleh tidak setuju pada paham Ahmadiyah. Saya pun begitu. Tapi, menyegel tempat ibadahnya adalah tindakan biadab.
#
#        like  like_isnumeric
# 259    1600               0
# 1939   1300               0
# 2181    100               0
# 3132   1800               0
# 3327   1700               0
# 4536    100               0
# 4943   4100               0
# 7668   1500               0
# 7774    100               0
# 7775   2500               0
# 8177   1400               0
# 8634   1300               0
# 8939   2200               0
# 9190    100               0
# 10856  1500               0
# 10873  1400               0
# 12678  1200               0

# %%
df.like = df.like.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13956 entries, 0 to 13957
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              13956 non-null  int64
#  1   id                 13956 non-null  object
#  2   name               13956 non-null  object
#  3   username           13956 non-null  object
#  4   date               13956 non-null  datetime64[ns]
#  5   reply_to           13956 non-null  object
#  6   content            13956 non-null  object
#  7   reply              13956 non-null  int32
#  8   retweet            13956 non-null  int32
#  9   like               13956 non-null  int32
#  10  retweet_isnumeric  13956 non-null  int64
#  11  like_isnumeric     13956 non-null  int64
# dtypes: datetime64[ns](1), int32(3), int64(3), object(5)
# memory usage: 1.7+ MB

# %% [markdown]
# ### language

# %%
df['lang'] = df.content.apply(lambda x: detect(x))

# %%
df['lang'].value_counts()
# Out:
# id    12994
# so      557
# en      329
# tl       27
# de       23
# sw        6
# no        4
# fr        3
# tr        2
# ur        2
# sl        2
# vi        1
# sv        1
# hr        1
# et        1
# pt        1
# pl        1
# ca        1
# Name: lang, dtype: int64

# %%
lang_to_drop = ['en', 'et', 'fr', 'no', 'ur', 'sl', 'sv']

# %%
df[['content', 'lang']][df.lang == 'sv']
# Out:
#                                         content lang
# 12868  Ahmadiyah är inte muslimer staghforallah   sv

# %%
df = df[~df.lang.isin(lang_to_drop)]

# %%
df.shape
# Out:
# (13614, 13)

# %% [markdown]
# ### Extract mentions

# %%
def extract_mentions(text):
    mentions = []
    text = text.split('\n')
    for item in text:
        for i in item.split():
            if i[0] == '@':
                mentions.append(i)
    return ' '.join(mentions)

# %%
df['mentions'] = df.content.apply(extract_mentions)
df[['content', 'mentions']][df.mentions != '']
# Out:
#                                                                                                                                            content  \
# 0                             Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :\n@Iskandargumay1
# 2      Sebenarnya mengomentari \n@permadiaktivis1\n lebih politis dari pada bicara HAM, mana berani para politikus menaggapi apalagi bersuara l...
# 51     Kapan Susi membela Minoritas, Ahmadiyah, Syiah ketika dianiaya ? Tapi kalau \n@permadiaktivis1\n sudah terbukti sepak terjangnya membela...
# 56                       Kapolri sudah datang ke DPP NU dan Muhamadiyah ,Kapan bisa ketemu dgn Pengurus Besar Jemaah Ahmadiyah ? \n@DivHumas_Polri
# 64                                                             ahmadiyah kapan nih bs beribadah tanpa dipasung SKB..\n@YaqutCQoumas\n @dedensujana
# ...                                                                                                                                            ...
# 13915                                    IDN TIMES JATENG \n@IDNTimesJateng\nMubaligh Ahmadiyah Lawan Diskriminasi Lewat Solidaritas Umat Beragama
# 13921  Belajar lah dengan ALIM ULAMA SOLEH dari kalangan Kyai/Gus/Habib Ahlussunnah wal Jama'ah. Jangan belajar dari Ulama Su'/Syi'ah/Ahmadiyah...
# 13935  PREMIERE VIDEO DOKUMENTER :"TITIK TERANG AHMADIYAH".\n\nSebuah video dokumenter yang menyajikan informasi dan fakta objektif terkait Ahm...
# 13946                                                                    @GUSDURians\n  up, maaf. Ini bukan penolakan gereja, LDII atau Ahmadiyah.
# 13949  Official Trailer : "TITIK TERANG AHMADIYAH".\n\nVideo dokumenter ini menceritakan kisah tentang para tokoh Dayak Kalimantan Barat yang m...
#
#                                                                                                              mentions
# 0                                                                                                     @Iskandargumay1
# 2                                                                                                    @permadiaktivis1
# 51                                                                                                   @permadiaktivis1
# 56                                                                                                    @DivHumas_Polri
# 64                                                                                         @YaqutCQoumas @dedensujana
# ...                                                                                                               ...
# 13915                                                                                                 @IDNTimesJateng
# 13921  @tni_ad @IBNUHUSEINATS @ali_hasan110 @mr_banan12 @abubakarsegaf @NovalAssegaf @ustad_alhabsyi @ustsegafbaharun
# 13935                                                                                                 @Iskandargumay1
# 13946                                                                                                     @GUSDURians
# 13949                                                                                                 @Iskandargumay1
#
# [1309 rows x 2 columns]

# %% [markdown]
# ## content_clean

# %%
content_clean = []
# Removing twitter mentions and links
for _, row in df.iterrows():
    content = row['content']
    mentions = row['mentions'].split()
    for mention in mentions:
        content = content.replace(mention, '')
    content = content.replace('\n', ' ')
    content = content.split()
    for i, item in enumerate(content):
        if 'http' in item:
            content.pop(i)
    content = ' '.join(content)
    content_clean.append(content)
df['content_clean'] = content_clean

# %% [markdown]
# ## Export

# %%
df_clean = df.drop(['index', 'retweet_isnumeric', 'like_isnumeric'], axis=1)
df_clean = df_clean.reset_index(drop=True)
df_clean.to_csv('./data/tweet-clean.csv', index=False)

# %%
df_new = pd.read_csv('./data/tweet-clean.csv')
df_new
# Out:
#                                         id                 name  \
# 0               DedenSujanaFeb12021Simak b         Deden Sujana
# 1       MuridIslamAhmadiyahFeb12021nah say  MuridIslamAhmadiyah
# 2               risrisismanFeb12021Sebenar         risris isman
# 3      MuridIslamAhmadiyahJan312021adakah   MuridIslamAhmadiyah
# 4      MuridIslamAhmadiyahJan312021itu vid  MuridIslamAhmadiyah
# ...                                    ...                  ...
# 13609         Beritabaru.coDec12021FBTI Ta        Beritabaru.co
# 13610               KETTLERDec12021Tuhanny              KETTLER
# 13611               KETTLERDec12021Tuhanny              KETTLER
# 13612               EkajuwaDec12021#IslamM              Ekajuwa
# 13613      NugrohoAdinegoroDec12021tah ben    Nugroho Adinegoro
#
#             username        date          reply_to  \
# 0       @dedensujana  2021-02-01               NaN
# 1        @MAhmadiyah  2021-02-01    @akbarnugrohoa
# 2          @risrisus  2021-02-01  @susipudjiastuti
# 3        @MAhmadiyah  2021-01-31    @akbarnugrohoa
# 4        @MAhmadiyah  2021-01-31    @akbarnugrohoa
# ...              ...         ...               ...
# 13609  @Beritabaruco  2021-12-01               NaN
# 13610      @inong911  2021-12-01        @AlloEfrat
# 13611      @inong911  2021-12-01     @AriaDinataK1
# 13612       @ekajuwa  2021-12-01               NaN
# 13613    @kangnugo85  2021-12-01          @nuke168
#
#                                                                                                                                            content  \
# 0                             Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :\n@Iskandargumay1
# 1                         nah saya ulang ya. silahkan temukan pernyataan dari Ahmadiyah langsung, bahwa nabi terakhir/penutup adala Ghulam Ahmad.
# 2      Sebenarnya mengomentari \n@permadiaktivis1\n lebih politis dari pada bicara HAM, mana berani para politikus menaggapi apalagi bersuara l...
# 3                 adakah pernyataan dari Ahmadiyah bahwa nabi penutup adalah Bukan Muhammad melainkan Mirza Ghulam Ahmad? silahkan tunjukan disini
# 4      itu video udh video udh menjelaskan penafsiran ahmadiyah soal Al-Azhab : 40 , malah dibilang ga bisa jelasin ok kalau ada pertanyaan soa...
# ...                                                                                                                                            ...
# 13609  FBTI Tasikmalaya Gelar Kemah Toleransi Demi Membuka Ruang Diskusi http://dlvr.it/SDWzSp #Ahmadiyah #forumbhinnekatunggalika #kemahtoleransi
# 13610  Tuhannya Islam satu Tuhannya Yahudi satu Tuhannya Kristen 1 Tuhannya Budha satu Tuhannya Hindu satu Tuhannya Konghucu satu Tuhannya Ahma...
# 13611  Tuhannya Islam satu Tuhannya Yahudi satu Tuhannya Kristen 1 Tuhannya Budha satu Tuhannya Hindu satu Tuhannya Konghucu satu Tuhannya Ahma...
# 13612  #IslamMempersatukanKita Kata Siapa? Rosul sendiri menyatakan Islam akan terpecah mjd berapa bagian. Itu terbukti dgn adanya Sunni, Syiah...
# 13613  tah bener 7 masjid weh nya\n1. Masjid agung alun2\n2. Masjid Persis\n3. Masjid NU\n4. Masjid Muhammadiyah\n5. Masjid pks\n6. Masjid waha...
#
#        reply  retweet  like lang          mentions  \
# 0          0        1     2   id   @Iskandargumay1
# 1          1        0     0   id               NaN
# 2          0        0     1   id  @permadiaktivis1
# 3          0        0     0   id               NaN
# 4          1        0     0   id               NaN
# ...      ...      ...   ...  ...               ...
# 13609      0        0     0   id               NaN
# 13610      1        0     0   id               NaN
# 13611      0        1     0   id               NaN
# 13612      0        1     0   id               NaN
# 13613      1        0     1   so               NaN
#
#                                                                                                                                      content_clean
# 0                                              Simak bagaimana sikap Khilafah Ahmadiyah terhadap Pancasila dan Demokrasi dalam link di bawah ini :
# 1                          nah saya ulang ya. silahkan temukan pernyataan dari Ahmadiyah langsung, bahwa nabi terakhir/penutup adala Ghulam Ahmad.
# 2      Sebenarnya mengomentari lebih politis dari pada bicara HAM, mana berani para politikus menaggapi apalagi bersuara lantang tentang kasus ...
# 3                 adakah pernyataan dari Ahmadiyah bahwa nabi penutup adalah Bukan Muhammad melainkan Mirza Ghulam Ahmad? silahkan tunjukan disini
# 4      itu video udh video udh menjelaskan penafsiran ahmadiyah soal Al-Azhab : 40 , malah dibilang ga bisa jelasin ok kalau ada pertanyaan soa...
# ...                                                                                                                                            ...
# 13609                        FBTI Tasikmalaya Gelar Kemah Toleransi Demi Membuka Ruang Diskusi #Ahmadiyah #forumbhinnekatunggalika #kemahtoleransi
# 13610  Tuhannya Islam satu Tuhannya Yahudi satu Tuhannya Kristen 1 Tuhannya Budha satu Tuhannya Hindu satu Tuhannya Konghucu satu Tuhannya Ahma...
# 13611  Tuhannya Islam satu Tuhannya Yahudi satu Tuhannya Kristen 1 Tuhannya Budha satu Tuhannya Hindu satu Tuhannya Konghucu satu Tuhannya Ahma...
# 13612  #IslamMempersatukanKita Kata Siapa? Rosul sendiri menyatakan Islam akan terpecah mjd berapa bagian. Itu terbukti dgn adanya Sunni, Syiah...
# 13613  tah bener 7 masjid weh nya 1. Masjid agung alun2 2. Masjid Persis 3. Masjid NU 4. Masjid Muhammadiyah 5. Masjid pks 6. Masjid wahabi 7. ...
#
# [13614 rows x 12 columns]

# %% [markdown]
# ## I think it's done
