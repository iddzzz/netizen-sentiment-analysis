# %% [markdown]
# ## Concatenating Data

# %%
import pandas as pd
import os

# %%
tw1 = pd.read_csv("./data/tweet-01.csv")
tw2 = pd.read_csv("./data/tweet-02.csv")
tw3 = pd.read_csv("./data/tweet-03.csv")
tw4 = pd.read_csv("./data/tweet-04.csv")
tw5 = pd.read_csv("./data/tweet-05.csv")
tw6 = pd.read_csv("./data/tweet-06.csv")
tw7 = pd.read_csv("./data/tweet-07.csv")
tw8 = pd.read_csv("./data/tweet-08.csv")

tw10 = pd.read_csv("./data/tweet-10.csv")
tw11 = pd.read_csv("./data/tweet-11.csv")

tw10_11 = pd.concat([tw10, tw11])
tw10_11[tw10_11.duplicated(keep=False)].sort_values('id')
# Out:
#                               id          name      username          date  \
# 372     IDNTimesOct232021Jemaah      IDN Times     @idntimes  Oct 23, 2021
# 434     IDNTimesOct232021Jemaah      IDN Times     @idntimes  Oct 23, 2021
# 229  billtemporoNov182021GAFATAR  bill temporo  @BillTemporo  Nov 18, 2021
# 208  billtemporoNov182021GAFATAR  bill temporo  @BillTemporo  Nov 18, 2021
# 201  billtemporoNov192021GAFATAR  bill temporo  @BillTemporo  Nov 19, 2021
# 179  billtemporoNov192021GAFATAR  bill temporo  @BillTemporo  Nov 19, 2021
# 163  billtemporoNov212021GAFATAR  bill temporo  @BillTemporo  Nov 21, 2021
# 141  billtemporoNov212021GAFATAR  bill temporo  @BillTemporo  Nov 21, 2021
# 121  billtemporoNov232021GAFATAR  bill temporo  @BillTemporo  Nov 23, 2021
# 100  billtemporoNov232021GAFATAR  bill temporo  @BillTemporo  Nov 23, 2021
# 80   billtemporoNov242021GAFATAR  bill temporo  @BillTemporo  Nov 24, 2021
# 101  billtemporoNov242021GAFATAR  bill temporo  @BillTemporo  Nov 24, 2021
# 444   billtemporoNov42021GAFATAR  bill temporo  @BillTemporo   Nov 4, 2021
# 468   billtemporoNov42021GAFATAR  bill temporo  @BillTemporo   Nov 4, 2021
# 440   billtemporoNov52021GAFATAR  bill temporo  @BillTemporo   Nov 5, 2021
# 418   billtemporoNov52021GAFATAR  bill temporo  @BillTemporo   Nov 5, 2021
# 394   billtemporoNov72021GAFATAR  bill temporo  @BillTemporo   Nov 7, 2021
# 359   billtemporoNov72021GAFATAR  bill temporo  @BillTemporo   Nov 7, 2021
# 330   billtemporoNov82021GAFATAR  bill temporo  @BillTemporo   Nov 8, 2021
# 351   billtemporoNov82021GAFATAR  bill temporo  @BillTemporo   Nov 8, 2021
# 631  billtemporoOct112021GAFATAR  bill temporo  @BillTemporo  Oct 11, 2021
# 609  billtemporoOct112021GAFATAR  bill temporo  @BillTemporo  Oct 11, 2021
# 421  billtemporoOct232021GAFATAR  bill temporo  @BillTemporo  Oct 23, 2021
# 335  billtemporoOct232021GAFATAR  bill temporo  @BillTemporo  Oct 23, 2021
# 204  billtemporoOct252021GAFATAR  bill temporo  @BillTemporo  Oct 25, 2021
# 162  billtemporoOct252021GAFATAR  bill temporo  @BillTemporo  Oct 25, 2021
# 93   billtemporoOct272021GAFATAR  bill temporo  @BillTemporo  Oct 27, 2021
# 65   billtemporoOct272021GAFATAR  bill temporo  @BillTemporo  Oct 27, 2021
# 32   billtemporoOct292021GAFATAR  bill temporo  @BillTemporo  Oct 29, 2021
# 53   billtemporoOct292021GAFATAR  bill temporo  @BillTemporo  Oct 29, 2021
# 709   billtemporoOct62021GAFATAR  bill temporo  @BillTemporo   Oct 6, 2021
# 687   billtemporoOct62021GAFATAR  bill temporo  @BillTemporo   Oct 6, 2021
# 663   billtemporoOct92021GAFATAR  bill temporo  @BillTemporo   Oct 9, 2021
# 642   billtemporoOct92021GAFATAR  bill temporo  @BillTemporo   Oct 9, 2021
#
#     reply_to                                            content  reply  \
# 372      NaN  Jemaah Ahmadiyah Depok harap bisa hidup rukun ...    NaN
# 434      NaN  Jemaah Ahmadiyah Depok harap bisa hidup rukun ...    NaN
# 229      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 208      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 201      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 179      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 163      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 141      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 121      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 100      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 80       NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 101      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 444      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 468      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 440      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 418      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 394      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 359      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 330      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 351      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 631      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 609      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 421      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 335      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 204      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 162      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 93       NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 65       NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 32       NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 53       NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 709      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 687      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 663      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
# 642      NaN    GAFATAR=Gerakan Fajar Nusantara=AHMADIYAH=KAFIR    NaN
#
#      retweet like
# 372      NaN    1
# 434      NaN    1
# 229      NaN  NaN
# 208      NaN  NaN
# 201      NaN  NaN
# 179      NaN  NaN
# 163      NaN  NaN
# 141      NaN  NaN
# 121      NaN  NaN
# 100      NaN  NaN
# 80       NaN  NaN
# 101      NaN  NaN
# 444      NaN  NaN
# 468      NaN  NaN
# 440      NaN  NaN
# 418      NaN  NaN
# 394      NaN  NaN
# 359      NaN  NaN
# 330      NaN  NaN
# 351      NaN  NaN
# 631      NaN  NaN
# 609      NaN  NaN
# 421      NaN  NaN
# 335      NaN  NaN
# 204      NaN  NaN
# 162      NaN  NaN
# 93       NaN  NaN
# 65       NaN  NaN
# 32       NaN  NaN
# 53       NaN  NaN
# 709      NaN  NaN
# 687      NaN  NaN
# 663      NaN  NaN
# 642      NaN  NaN
